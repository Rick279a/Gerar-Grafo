# %% [markdown]
# <a href="https://colab.research.google.com/github/Rick279a/Gerar-Grafo/blob/main/ALgoritmoBuscaGrafos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Gerar Grafo**

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# Função para criar um grafo de exemplo

# %%
def criar_grafo_exemplo():
    G = nx.Graph()

   # Adiciona nós
    G.add_nodes_from(["A", "B", "C", "D", "E", "F"])

    # Adiciona arestas
    G.add_edges_from([("A", "B"), ("A", "C"), ("B", "C"), ("C", "D"), ("C", "F"), ("D", "E"), ("E", "F"), ("F", "A"), ("F", "D")])

    return G

# %% [markdown]
# Função para desenhar o grafo

# %%
def desenhar_grafo(grafo):
    pos = nx.spring_layout(grafo)  # Define a posição dos nós
    nx.draw(grafo, pos, with_labels=True, font_weight='bold', node_size=700, node_color='skyblue', font_size=10)
    plt.show()

# %% [markdown]
# Criar um grafo de exemplo

# %%
grafo_exemplo = criar_grafo_exemplo()

# %% [markdown]
# Desenhar o grafo

# %%
desenhar_grafo(grafo_exemplo)

# %% [markdown]
# # **Algoritmo de Busca - "Busca Cega"**

# %%
from collections import deque

# %% [markdown]
# Função para detectar o menor caminho à ser percorrido:

# %%
def busca_largura(grafo, inicio, objetivo):
    fila = deque([(inicio, [inicio])])
    print(str(fila))

    while fila:
        (vertice, caminho) = fila.popleft()
        print("vertice: " + str(vertice))
        print("caminho: " + str(caminho))
        for vizinho in grafo[vertice]:
            print("vizinho: " + str(vizinho))
            if vizinho not in caminho:
                if vizinho == objetivo:
                    return caminho + [vizinho]
                else:
                    fila.append((vizinho, caminho + [vizinho]))

# %%
fila = deque([('A', ['A'])])
print(str(fila))
(vertice, caminho) = fila.popleft()
print(str((vertice, caminho)))
# Out:
# deque([('A', ['A'])])
# ('A', ['A'])

# %% [markdown]
# GRAFO Exemplo:

# %%
grafo_exemplo = {
    "A": ["B", "C"],
    "B": ["A", "C", "E"],
    "C": ["A", "F", "D"],
    "D": ["B", "E"],
    "E": ["B", "H"],
    "F": ["C", "A"],
}

# %% [markdown]
# Chamar a função para poder encontrar o menor caminho para poder chegar até o objetivo esperado.

# %%
resultado = busca_largura(grafo_exemplo, 'A', 'H')
print("Caminho mais curto:", resultado)
# Out:
# deque([('A', ['A'])])
# vertice: A
# caminho: ['A']
# vizinho: B
# vizinho: C
# vertice: B
# caminho: ['A', 'B']
# vizinho: A
# vizinho: C
# vizinho: E
# vertice: C
# caminho: ['A', 'C']
# vizinho: A
# vizinho: F
# vizinho: D
# vertice: C
# caminho: ['A', 'B', 'C']
# vizinho: A
# vizinho: F
# vizinho: D
# vertice: E
# caminho: ['A', 'B', 'E']
# vizinho: B
# vizinho: H
# Caminho mais curto: ['A', 'B', 'E', 'H']
